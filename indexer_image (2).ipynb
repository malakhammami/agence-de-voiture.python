# %%
#Obtention des images à partir d'un dossier 
import os
Voitures = os.listdir('Voitures')
Voitures
# Out:
# ['40621677762374.jpg',
#  '81257_max.jpg',
#  '8b1bf5b4-d981-4bd6-852c-5465f9f1894e.jpg']

# %%
image_path= os.path.join('Voitures', Voitures[1])
image_path
# Out:
# 'Voitures\\81257_max.jpg'

# %%
from skimage.io import imread

I=imread(image_path)

# %%
import matplotlib.pyplot as plt
plt.imshow(I)

# %%
from skimage import color
I = color.rgb2gray(I)
plt.imshow(I, cmap='gray')

# %%
import numpy as np
I1 = np.resize(I, (20,20))

# %%
I1.shape
# Out:
# (20, 20)

# %%
I1= I1.reshape(20*20)
I1.shape
# Out:
# (400,)

# %%
I1= I1.flatten()
I1
# Out:
# array([0.40624392, 0.38858549, 0.37289922, ..., 0.58148431, 0.66383725,
#        0.6834451 ])

# %%
images=[]
for file in os.listdir('Voitures'):
    image_path = os.path.join('Voitures', file)
    images.append(image_path)
images
# Out:
# ['Voitures\\40621677762374.jpg',
#  'Voitures\\81257_max.jpg',
#  'Voitures\\wallys-car-photo.jpg']

# %%
List=[]
for image_path in images:
    I=imread(image_path)
    I = color.rgb2gray(I)
    I1 = np.resize(I, (20,20))
    I1= I1.reshape(20*20)
    I1= I1.flatten()
    List.append(I1)

# %%
List
# Out:
# [array([0.84468667, 0.8525298 , 0.83684353, 0.79593843, 0.79201686,
#         0.82787647, 0.8581102 , 0.86595333, 0.86005961, 0.86229961,
#         0.86116078, 0.86087804, 0.86311804, 0.86058039, 0.86282039,
#         0.86282039, 0.86255255, 0.86255255, 0.86255255, 0.86255255,
#         0.86255255, 0.86255255, 0.86255255, 0.86255255, 0.86255255,
#         0.86255255, 0.86255255, 0.86255255, 0.86255255, 0.86255255,
#         0.86255255, 0.86255255, 0.86087804, 0.86087804, 0.86087804,
#         0.86087804, 0.86087804, 0.86087804, 0.86087804, 0.86087804,
#         0.86087804, 0.86087804, 0.86087804, 0.86087804, 0.86087804,
#         0.86087804, 0.86087804, 0.86087804, 0.86177961, 0.86177961,
#         0.86177961, 0.85980745, 0.86064078, 0.85840078, 0.86006745,
#         0.85837804, 0.86622118, 0.82643216, 0.74183922, 0.65220863,
#         0.57964824, 0.49365647, 0.35248   , 0.21690667, 0.18595765,
#         0.25262431, 0.12599529, 0.20386118, 0.27079569, 0.33325804,
# ...
